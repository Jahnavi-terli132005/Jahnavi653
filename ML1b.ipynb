# %%
s1=[40,None,60,50,90]
s2=[65,46,34,None,78]
s3=[90,None,76,78,34]
s4=[100,45,46,None,67]

# %%
from google.colab import drive
drive.mount(r'/content/drive')
# Out:
# Mounted at /content/drive

# %%
marks=[s1,s2,s3,s4]

# %%
marks
# Out:
# [[40, None, 60, 50, 90],
#  [65, 46, 34, None, 78],
#  [90, None, 76, 78, 34],
#  [100, 45, 46, None, 67]]

# %%
import pandas as pd
df=pd.DataFrame(marks,columns=['C','C++','Java','Python','R'],index=[1,2,3,4])

# %%
df
# Out:
#      C   C++  Java  Python   R
# 1   40   NaN    60    50.0  90
# 2   65  46.0    34     NaN  78
# 3   90   NaN    76    78.0  34
# 4  100  45.0    46     NaN  67

# %%
df.isnull()
# Out:
#        C    C++   Java  Python      R
# 1  False   True  False   False  False
# 2  False  False  False    True  False
# 3  False   True  False   False  False
# 4  False  False  False    True  False

# %%
df.isnull().sum()
# Out:
# C         0
# C++       2
# Java      0
# Python    2
# R         0
# dtype: int64

# %%
csvf=df.to_csv('/content/drive/MyDrive/Colab Notebooks/marks.csv')

# %%
fr=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/marks.csv')
fr
# Out:
#    Unnamed: 0    C   C++  Java  Python   R
# 0           1   40   NaN    60    50.0  90
# 1           2   65  46.0    34     NaN  78
# 2           3   90   NaN    76    78.0  34
# 3           4  100  45.0    46     NaN  67

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean')
df_cleaned=pd.DataFrame(imputer.fit_transform(numeric_df),columns=numeric_df.columns)
print("\nCleaned Dataset: ")
print(df_cleaned)
# Out:
# Cleaned Dataset:
#    Unnamed: 0      C   C++  Java  Python     R
# 0         1.0   40.0  45.5  60.0    50.0  90.0
# 1         2.0   65.0  46.0  34.0    64.0  78.0
# 2         3.0   90.0  45.5  76.0    78.0  34.0
# 3         4.0  100.0  45.0  46.0    64.0  67.0

# %%
df1=df.ffill()
# Out:
#      C   C++  Java  Python   R
# 1   40   NaN    60    50.0  90
# 2   65  46.0    34    50.0  78
# 3   90  46.0    76    78.0  34
# 4  100  45.0    46    78.0  67

# %%
df1.bfill()
# Out:
#      C   C++  Java  Python   R
# 1   40  46.0    60    50.0  90
# 2   65  46.0    34    50.0  78
# 3   90  46.0    76    78.0  34
# 4  100  45.0    46    78.0  67

# %%
data=[['arun',2,5,20000],
      ['']]
